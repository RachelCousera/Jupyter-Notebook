# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Rachel Hurn__
# Data scientist

# %% [markdown]
# _I am interested in Data Science because I can see it has huge potential in informing education policy in the future. Data science can help inform what the healthiest, happiest and most effective schools should look like. Policy can then be devised to make this happen._

# %% [markdown]
# ### My code will add three numbers together ###

# %%
1+2+3
# Out:
# 6

# %% [markdown]
# 1. Physical Health
# 2. Mental Health
# 3. Teaching and learning
#
# ![puppies.jpg](attachment:6b92053f-cc59-40c7-be79-aa9018ce7d8e.jpg)
#
# __https://www.goodhousekeeping.com/life/pets/g4531/cutest-dog-breeds/__
